# %%
from scipy.optimize import fmin_l_bfgs_b
from sklearn import cross_validation
from sklearn import preprocessing
from sklearn import decomposition
import numpy as np
import scipy as sp

# %% [markdown]
# ### Load Data

# %%
norm = preprocessing.Normalizer()
X_train_in = np.loadtxt(open("../data/train.csv","rb"),delimiter=",",skiprows=1, usecols=range(1,94))
X_train_in = norm.fit_transform(X_train_in)

y_train_in = np.loadtxt(open("../data/train.csv","rb"),dtype=str,delimiter=",",skiprows=1, usecols=[94])
y_train_in = np.array([int(c[-2]) for c in y_train_in])  # Parse classes from Class_1 into 1

X_test_in = np.loadtxt(open("../data/test.csv","rb"),delimiter=",",skiprows=1, usecols=range(1,94))
X_test_in = norm.transform(X_test_in)

# %% [markdown]
# ### Preprocesse Data

# %%
# Shuffle
XY = np.hstack((X_train_in, np.matrix(y_train_in).T))
np.random.shuffle(XY)
X_train = XY[:, :X_train.shape[1]]
y_train = XY[:, -1].T.tolist()
y_train = np.array(y_train[0])

# %%
y_train.shape
# Out:
# (50000,)

# %%
# Pca

pca = decomposition.PCA(n_components=20)
X_train_pca = pca.fit_transform(X_train)

# %%
# Normalize 

# with l1. We want to have linear corelation because we have multiple classes. 
X_train_normalized = preprocessing.normalize(X_train_pca, norm='l1', axis=0, copy=True)

# %%
# Class number to vector: 4 = [0 0 0 1 0 0 0 0 0]

NUM_OF_CLASSES = len( np.unique(y_train))  # Warning: number of classes must go from 1 to n
I = np.identity(NUM_OF_CLASSES)
y_train_extended = np.array( [ I[y-1] for y in y_train])

# %%
y_train_extended.shape
# Out:
# (50000, 9)

# %% [markdown]
# ###### Testing box

# %%
# Testing normalization
m = np.matrix([[0.5,2.0,3.0], [0.5,8.0,3.0]])
normalized_m = preprocessing.normalize(m, axis=0)

# %%
m
# Out:
# matrix([[ 0.70710678,  0.24253563,  0.70710678],
#         [ 0.70710678,  0.9701425 ,  0.70710678]])

# %%
np.hstack((m, m))
# Out:
# matrix([[ 0.70710678,  0.24253563,  0.70710678,  0.70710678,  0.24253563,
#           0.70710678],
#         [ 0.70710678,  0.9701425 ,  0.70710678,  0.70710678,  0.9701425 ,
#           0.70710678]])

# %% [markdown]
# ### Helper Functions

# %%
def add_ones(X):
    return np.column_stack(X, (np.ones(len(X))))

def add_one(X):
    return np.append(X, 1)

def del_one(X):
    return X[:-1]

def sigmoid(z):
    return 1/(1+np.exp(-z))

# %% [markdown]
# ### Classifier

# %%
class NeuralNetClassifier():
    """Neural network classifier based on a set of binary classifiers."""
    def __init__(self, h, thetas):
        self.thetas = thetas  # model parameters
        self.h = h
        
    def predict(self, x_):
        y_hat = self.h(x_, self.thetas)
        return y_hat

# %% [markdown]
# ### Learner

# %%
class NeuralNetLearner():
    def __init__(self, arch, g=sigmoid, lambda_=1e-5):
        self.arch = arch
        self.n_levels = len(arch)
        self.g = g
        self.lambda_ = lambda_
        self.theta_shape = np.array([ ( arch[i] + 1, arch[i + 1]) for i in range( len( arch) - 1)])
        ind = np.array( [ sh1 * sh2 for sh1, sh2 in self.theta_shape])
        self.theta_ind = np.cumsum( ind[:-1])  # last index falls out of the boundary
        self.theta_len = sum(ind)
    
    def init_thetas(self, epsilon=1e-5):
        """Return thetas with random values"""
        np.random.seed(42)
        return np.random.rand(self.theta_len) * 2 * epsilon - epsilon
    
    def shape_thetas(self, thetas):
        """Return list of thetas at particular level"""
        t = np.split(thetas, self.theta_ind)
        return np.array( [t[i].reshape(shape) for i, 
                          shape in enumerate(self.theta_shape)])
    
    def feedforward(self, a_, thetas):
        """Feed forward, prediction, add ones to the end for bias"""
        thetas = self.shape_thetas(thetas)
        activationsByLevel = [a_]
        for theta in thetas: 
            a1_ = add_one(a_)  # add bias
            print(a1_.shape, theta.shape)
            a_ = self.g(a1_.dot(theta))
            activationsByLevel.append(a_)
        return np.array(activationsByLevel)
    
    def backprop(self, thetas):
        """Add bias to the end"""

        activations = self.feedforward( self.x_, thetas)
        thetas = self.shape_thetas( thetas)
        # output error
        err = - np.multiply( self.y_ - activations[-1],  
                             np.multiply( activations[-1], 1-activations[-1])) 
               
        errors = [0] * self.n_levels
        errors[self.n_levels - 1] = err 
        
        levels = list(range(0, self.n_levels-1))
        for l in levels[::-1]:  # reverse
            th_ = thetas[l] * np.matrix(err).T
            th_ = th_.T
            ac_ = add_one( activations[l] ) # add bias
            ac_ = np.multiply( ac_, (1 - ac_))
            errors[l] = np.array( np.multiply( th_, ac_) )[0]
            err = del_one(errors[l])

        return np.array(errors), activations
    
    def J(self, thetas):
        return 1/2 * sum(((self.feedforward( self.x_, thetas)[-1] - self.y_)**2)) 
        # add [0] because we have to remove matrix form first, then sum it together

    def Jgrad(self, thetas):
        errors, activations = self.backprop( thetas)
        grad = np.array([])
        for l in range(self.n_levels-1):
            ac_ = add_one(activations[l])
            err = del_one(errors[l+1]) if l != self.n_levels-2 else errors[l+1]
            cur_grad = np.matrix(err).T.dot(np.matrix(ac_)).T
            grad = np.append(grad , cur_grad)
        return np.array(grad)
        
    def grad_approx(self, thetas, e=1e-1):
        return np.array([(self.J(thetas+eps) - self.J(thetas-eps))/(2*e)
                         for eps in np.identity(len(thetas)) * e])
    
    def fit(self, x_, y_, thetas0=None):
        """ x_ is a vector, y is a class between 1 and sth"""
        self.x_ = x_
        self.y_ = y_
        
        thetas0 = thetas0 if thetas0 != None else self.init_thetas()
        self.thetas = thetas0
        thetas, _, _ = fmin_l_bfgs_b(func = self.J,
                                           x0 = thetas0,
                                           fprime = self.Jgrad,
                                           factr=1000)
        self.thetas = thetas
        return thetas
    
    def predict(self, x_):
        return self.feedforward( x_, self.thetas)

# %% [markdown]
# ### Testing

# %%
x_ = X_train[0, :5]
y = y_train_extended[0]
lr = NeuralNetLearner([len(x_), 2,  9])
r = lr.fit(x_, y)

# %% [raw]
# # Test atributes and some minor functions of a learner
#
# print( "Testing shape\n", lr.theta_shape)
# print( "Testing indices\n", lr.theta_ind)
# print( "Testing theta lenght\n", lr.theta_len)
# print( "Testing theta shape\n", lr.shape_thetas( thetas))

# %% [raw]
# # Test feed forward
#
# print( "Test feed forward:")
# print( lr.feedforward(lr.x_, lr.thetas))

# %% [raw]
# # Test back propagation
#
# print( "Test errors and activations")
# errors, acts = lr.backprop(lr.thetas)
# print( errors.shape, acts.shape)

# %%
# Test cost function

print( "Cost function:", lr.J(lr.thetas))
# Out:
# Cost function: 3.23919496017e-05

# %%
# Test gradient function 

print( "Grad. function:", lr.Jgrad(lr.thetas))
# Out:
# Grad. function: [  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -5.37324900e-06  -5.37318500e-06
#   -6.83911438e-06   6.83916562e-06   6.83917856e-06   6.83905224e-06
#    6.83903238e-06   6.83906844e-06   6.83912977e-06   6.83916095e-06
#    6.83908827e-06  -6.83911862e-06   6.83916986e-06   6.83918280e-06
#    6.83905649e-06   6.83903662e-06   6.83907269e-06   6.83913401e-06
#    6.83916520e-06   6.83909251e-06  -7.17890312e-06   7.17895690e-06
#    7.17897049e-06   7.17883790e-06   7.17881704e-06   7.17885490e-06
#    7.17891928e-06   7.17895201e-06   7.17887571e-06]

# %%
# Test gradient approximation

print( "Grad. approx:", lr.grad_approx(lr.thetas, e=1e-5))
# Out:
# Grad. approx: [  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -5.37324901e-06  -5.37318501e-06
#   -6.83911436e-06   6.83916562e-06   6.83917856e-06   6.83905224e-06
#    6.83903238e-06   6.83906844e-06   6.83912977e-06   6.83916095e-06
#    6.83908827e-06  -6.83911862e-06   6.83916986e-06   6.83918280e-06
#    6.83905649e-06   6.83903662e-06   6.83907269e-06   6.83913401e-06
#    6.83916520e-06   6.83909251e-06  -7.17890312e-06   7.17895690e-06
#    7.17897049e-06   7.17883790e-06   7.17881704e-06   7.17885490e-06
#    7.17891928e-06   7.17895201e-06   7.17887571e-06]

# %%
# Test difference
print( "grad - grad.aprox =", sum( lr.Jgrad(lr.thetas) - lr.grad_approx(lr.thetas, e=1e-5) ))  # = -2.310293595541139e-12
# Out:
# grad - grad.aprox = -9.47770490968e-15

# %% [markdown]
# ### Batch Sequential

# %%
# stohastic training:   size = 1
# batch training:       size = num of samples .... TU MORAS PAZITI. SESTEVATI MORAS GRADIENTE, NE THERE
# batch sequential:     otherwise
class BatchSeq():
    def __init__(self, learner, size=1):
        self.learner = learner
        self.size = size
        
    def update_thetas(self, X, y_, thetas=None):
        list_of_thetas = [ self.learner.fit( X[i], y_[i], thetas) for i in range( X.shape[0])]   # list of thetas
        new_thetas = sum( list_of_thetas) / len(list_of_thetas)
        return new_thetas
        
    def fit_thetas(self, X, y_, thetas=None):
        # devide into subset of 100 elements
        # we have 50 000 / 100 = 500 subsets
        size = self.size
        # num of samples = 1130 = 0, 100, ..., 900, 1000, 1130 (last block takes all remainded)
        split = [ [lo, lo+size] 
                          for lo in range( 0, X.shape[0], size)
                        ] if X.shape[0] >= size else [[0, 0]]
        split[-1][-1] = X.shape[0]
        for lo, hi in split:   # we remove 2, cuz we will examine it at the end
            thetas = self.update_thetas( X[lo:hi, :], y_[lo:hi], thetas)
        return thetas
    
    def fit(self, X, y_):
        eps = 1e-8
        thetas = self.learner.init_thetas()
        # run until the error is very small
        while True:
            prev = thetas
            thetas = self.fit_thetas(X, y_, thetas)
            if (sum( abs(thetas - prev) > eps ) == 0):
                break
        model = NeuralNetClassifier(self.learner.predict, thetas)
        return model

# %% [raw]
# size = 100
# split_indices = [ [lo, lo+size] for lo in range( 0, 1130-size, size)]
# split_indices[-1][-1] = 1130
# split_indices

# %%
threshold = 100
X = X_train_normalized[:threshold, :]
y_ = y_train_extended[:threshold]
lr = NeuralNetLearner([X.shape[1], 2,  9])
batchseq = BatchSeq(lr, 1)

# %%
model = batchseq.fit(X, y_)
# Out:
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,)
#  (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,)
#  (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# ...
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
# (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)
#  (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,) (21, 2)
# (3,) (3, 9)
# (21,)

# %%
model.thetas
# Out:
# array([ -1.19383033e-04,  -1.72466909e-04,   8.78506990e-05,
#          1.08599013e-04,   1.45962268e-04,  -1.73481085e-04,
#         -2.28780257e-04,   3.86641749e-04,   2.74384155e-04,
#         -2.43485485e-04,   4.73656364e-04,  -9.67305053e-05,
#         -1.54257807e-04,  -2.12008207e-04,   4.48897567e-04,
#         -1.83589298e-04,   3.98468325e-04,  -3.47547548e-04,
#         -2.25049277e-04,   3.71285531e-04,  -7.61219509e+00,
#         -4.85024669e+00,  -4.85024610e+00,  -7.73939470e+00,
#          3.78931666e+01,  -4.85019560e+00,   1.17885804e+01,
#         -4.85022829e+00,   4.67687243e+00,  -4.85025123e+00,
#         -3.05041246e+01,  -3.05041356e+01,   1.41575697e+01,
#          4.27441278e+01,  -3.05035489e+01,  -1.94530807e+01,
#         -3.05039345e+01,  -2.30892901e+01,  -3.05041714e+01])

# %% [markdown]
# #### Cross Validation

# %%
from sklearn import metrics

# %%
def evaluate(pred, real):
    return metrics.log_loss(real, pred)

# %%
def my_cross_validation(X, Y, arch):
    k = 5
    S = []
    kf = cross_validation.KFold(len(y), n_folds=k, shuffle=True)
    for train_index, test_index in kf:
        # Split
        X_train, X_test = X[train_index], X[test_index]
        Y_train, Y_test = Y[train_index], Y[test_index]
        # Predict
        print(X_train.shape, Y_train.shape)
        learner = NeuralNetLearner(arch)
        bs = BatchSeq( learner)
        model = bs.fit(X_train, Y_train)
        predicted = model.predict(X_test)
        # Evaluate
        score = evaluate(predicted, Y_test)
        S.append( score )
    S = np.array(S)
    return(np.mean(S))

# %%
arch = [X_train.shape[1], 2, NUM_OF_CLASSES]
my_cross_validation(X, y_train_extended, arch)
# Out:
# (7, 20) (7, 9)
# OK
# (21,) (94, 2)
# -c:80: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-d558d3642647> in <module>()
#       1 arch = [X_train.shape[1], 2, NUM_OF_CLASSES]
# ----> 2 my_cross_validation(X, y_train_extended, arch)
#
# <ipython-input-139-b22a203d7881> in my_cross_validation(X, Y, arch)
#      12         print( "OK")
#      13         bs = BatchSeq( learner)
# ---> 14         model = bs.fit(X_train, Y_train)
#      15         predicted = model.predict(X_test)
#      16         # Evaluate
#
# <ipython-input-133-e901fdb40db9> in fit(self, X, y_)
#      31         while True:
#      32             prev = thetas
# ---> 33             thetas = self.fit_thetas(X, y_, thetas)
#      34             if (sum( abs(thetas - prev) > eps ) == 0):
#      35                 break
#
# <ipython-input-133-e901fdb40db9> in fit_thetas(self, X, y_, thetas)
#      22         split[-1][-1] = X.shape[0]
#      23         for lo, hi in split:   # we remove 2, cuz we will examine it at the end
# ---> 24             thetas = self.update_thetas( X[lo:hi, :], y_[lo:hi], thetas)
#      25         return thetas
#      26
#
# <ipython-input-133-e901fdb40db9> in update_thetas(self, X, y_, thetas)
#       8
#       9     def update_thetas(self, X, y_, thetas=None):
# ---> 10         list_of_thetas = [ self.learner.fit( X[i], y_[i], thetas) for i in range( X.shape[0])]   # list of thetas
#      11         new_thetas = sum( list_of_thetas) / len(list_of_thetas)
#      12         return new_thetas
#
# <ipython-input-133-e901fdb40db9> in <listcomp>(.0)
#       8
#       9     def update_thetas(self, X, y_, thetas=None):
# ---> 10         list_of_thetas = [ self.learner.fit( X[i], y_[i], thetas) for i in range( X.shape[0])]   # list of thetas
#      11         new_thetas = sum( list_of_thetas) / len(list_of_thetas)
#      12         return new_thetas
#
# <ipython-input-141-735e5ce0dc12> in fit(self, x_, y_, thetas0)
#      83                                            x0 = thetas0,
#      84                                            fprime = self.Jgrad,
# ---> 85                                            factr=1000)
#      86         self.thetas = thetas
#      87         return thetas
#
# C:\Python34\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback)
#     185
#     186     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 187                            **opts)
#     188     d = {'grad': res['jac'],
#     189          'task': res['message'],
#
# C:\Python34\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, **unknown_options)
#     313                 # minimization routine wants f and g at the current x
#     314                 # Overwrite f and g:
# --> 315                 f, g = func_and_grad(x)
#     316         elif task_str.startswith(b'NEW_X'):
#     317             # new iteration
#
# C:\Python34\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     264     else:
#     265         def func_and_grad(x):
# --> 266             f = fun(x, *args)
#     267             g = jac(x, *args)
#     268             return f, g
#
# C:\Python34\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     280     def function_wrapper(*wrapper_args):
#     281         ncalls[0] += 1
# --> 282         return function(*(wrapper_args + args))
#     283
#     284     return ncalls, function_wrapper
#
# <ipython-input-141-735e5ce0dc12> in J(self, thetas)
#      56
#      57     def J(self, thetas):
# ---> 58         return 1/2 * sum(((self.feedforward( self.x_, thetas)[-1] - self.y_)**2))
#      59         # add [0] because we have to remove matrix form first, then sum it together
#      60
#
# <ipython-input-141-735e5ce0dc12> in feedforward(self, a_, thetas)
#      28             a1_ = add_one(a_)  # add bias
#      29             print(a1_.shape, theta.shape)
# ---> 30             a_ = self.g(a1_.dot(theta))
#      31             activationsByLevel.append(a_)
#      32         return np.array(activationsByLevel)
#
# ValueError: shapes (21,) and (94,2) not aligned: 21 (dim 0) != 94 (dim 0)
